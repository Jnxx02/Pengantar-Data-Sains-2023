# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/drive/Othercomputers/My Laptop/Kuliah/SEMESTER 3/Pengantar Data Sains/Pengantar-Data-Sains-2023/Pertemuan 9/datarumah.xlsx')
data.head()
# Out:
#    Harga rumah (1000s)(y)  Feet Persegi(x)
# 0                     245             1400
# 1                     312             1600
# 2                     279             1700
# 3                     308             1875
# 4                     199             1100

# %%
import seaborn as sns
import matplotlib as plt

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

harga_rumah = data[['Harga rumah (1000s)(y)']]
luas_rumah = data[['Feet Persegi(x)']]

reg.fit(luas_rumah, harga_rumah)
# Out:
# LinearRegression()

# %%
b1 = reg.coef_
b0 = reg.intercept_
print (b0, b1)
# Out:
# [98.24832962] [[0.10976774]]

# %%
sns.scatterplot(data, x = 'Feet Persegi(x)', y = 'Harga rumah (1000s)(y)')
# Out:
# <Axes: xlabel='Feet Persegi(x)', ylabel='Harga rumah (1000s)(y)'>

# %%
y_pred = reg.predict(luas_rumah)
y_pred
# Out:
# array([[251.92316258],
#        [273.87671015],
#        [284.85348393],
#        [304.06283805],
#        [218.99284123],
#        [268.38832326],
#        [356.20251352],
#        [367.17928731],
#        [254.66735603],
#        [284.85348393]])

# %%
# sns.lineplot(data, x = 'Feet Persegi(x)', y = 'Harga rumah (1000s)(y)')
sns.regplot(data, x = 'Feet Persegi(x)', y = 'Harga rumah (1000s)(y)')
# Out:
# <Axes: xlabel='Feet Persegi(x)', ylabel='Harga rumah (1000s)(y)'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(harga_rumah, y_pred)
mse = mean_squared_error(harga_rumah, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(harga_rumah, y_pred)

print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R2: ', r2)
# Out:
# MAE:  31.03811644925231
# MSE:  1366.5565224307989
# RMSE:  36.96696528565469
# R2:  0.5808173118722721
